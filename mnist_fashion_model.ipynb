# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

data=keras.datasets.fashion_mnist

# %%
(train_images, train_labels),(test_images, test_labels)=data.load_data()
print(train_labels[1])
# Out:
# 0

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
plt.imshow(train_images[7], cmap=plt.cm.binary )
plt.show()

# %%
#building our model


#what does flatten layer do?
#2d to 1d data
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation="relu"),
    keras.layers.Dense(10,activation="softmax")
])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.fit(train_images, train_labels,epochs=5)
test_loss,test_acc=model.evaluate(test_images,test_labels)
print("Tested ACc:",test_acc)



#the more epochs u do the less accuraccy it becomes,
#it also overfits the model
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4983 - accuracy: 0.8242
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3731 - accuracy: 0.8656
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3365 - accuracy: 0.8774
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3116 - accuracy: 0.8853
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2949 - accuracy: 0.8902
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3420 - accuracy: 0.8782
# Tested ACc: 0.8781999945640564

# %%
class_names=['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle Boot']

# %%
#using our model
prediction = model.predict(test_images)
for i in range(5):
  plt.grid(False)
  plt.imshow(test_images[i],cmap=plt.cm.binary)
  plt.xlabel("Actual: "+class_names[test_labels[i]])
  plt.title("Prediction"+class_names[np.argmax(prediction[i])])
  plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
5
